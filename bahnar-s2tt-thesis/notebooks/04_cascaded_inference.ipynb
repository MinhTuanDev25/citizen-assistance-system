# %% [markdown]
# # 04_cascaded_inference
#
# Placeholder — sẽ implement sau khi Notebook 01 xuất manifests.
#
# Đọc input từ: `data/manifests/rq1_*.csv`

# %%
import torch

print("Torch:", torch.__version__)
print("CUDA:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else None)
# Out:
# Torch: 2.11.0+cpu
# CUDA: False
# GPU: None
